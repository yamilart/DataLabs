# %% [markdown]
# ## Travelling around the Canary Islands

# %% [markdown]
# __[Who](#boyfriend)                  [Favs](#favourite)                  [Loves](#loves)                  [More](#more)__

# %% [markdown]
# <a id="boyfriend"></a>
# It's my __boyfriends__ favourite holidays destination

# %%
def boyfriend():
    name = str(input("What's your boyfriends name?: "))
    print("My boyfriends name is " + str(name))
    return
boyfriend()
# Out:
# What's your boyfriends name?: Renato
# My boyfriends name is Renato

# %% [markdown]
# ![Best-Resorts-to-Swim-with-Sea-Turtles-Turkey-Iztuzu.jpeg](attachment:Best-Resorts-to-Swim-with-Sea-Turtles-Turkey-Iztuzu.jpeg)

# %% [markdown]
# He would probably __kill me__ if I update a picture of him anywhere so here's a picture of his __favourite animal__ instead :)

# %% [markdown]
# <a id="favourite"></a>
# A little info about his __favourite island__

# %%
def holidays():
    question1 = str(input("What's your favourite Canary Island?: "))
    question2 = str(input("What do you like doing there?: "))
    print(f"Your favourite holidays destination is {question1} because you like {question2}")
    return
holidays()

# %% [markdown]
# ![graciosa-beach.jpeg](attachment:graciosa-beach.jpeg)

# %% [markdown]
# <a id="loves"></a>
# In the canary islands my boyfriend basically __loves__:
# - __Swimming__ and doing SUP
# - __Hiking__ and exploring the __volcanoes__
# - __Stargazing__

# %% [markdown]
# <a id="more"></a>
# Want to see __more__ about the islands?
#
# [Watch video](https://www.youtube.com/watch?v=3bOFEXrE9RI)
