# %% [markdown]
# # Computer Vision

# %% [markdown]
# ## First Task
#
# In a jupyter notebook, using the appropriate markdown method include at least one link to a website, news article or blog which discusses ethical issues with computer vision applications and add your personal thoughts and interpretation of this issue.

# %% [markdown]
# [**Ethical Issues in Computer Vision**](https://innodata.com/ethical-issues-in-computer-vision-and-strategies-for-success/)
#
# - This is literally the title of the task but I found this article really interesting since it mentions several issues and also possible 'solutions' and best practices to help turn computer vision and AI into a friend more than a foe.

# %% [markdown]
# ## Second Task
#
# Use the https://vision-explorer.allenai.org/text_to_image_generation to generate an image from a caption you provide (choosing a theme from the drop down list), which you should display inside your notebook with the caption you provided and an evaluation of how good a job you feel the machine has done.
# - hint: you will need an image display method.

# %% [markdown]
# My input: Two dows playing in the park

# %%
# %matplotlib inline
from IPython.display import Image
Image('image.png')

# %% [markdown]
# Well... they looks like stuff from a nightmare honestly. The park looks nice

# %% [markdown]
# ## Third Task
#
# Read [this blog article](https://thedatafrog.com/en/articles/dogs-vs-cats/). Link the url to your notebook using the appropriate markdown technique and add a summary into your notebook (as markdown) of any image processing steps you saw the author employ.

# %% [markdown]
# [**Dogs vs. Cats**](https://thedatafrog.com/en/articles/dogs-vs-cats/)
#
# - The author used **keras** to build the **image classification network** and then applied some **optimizers and augmented the dataset** to make sure the model has a **good prediction even in the most difficult cases**.
